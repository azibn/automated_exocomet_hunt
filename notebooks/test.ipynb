# %%
cd ..
# Out:
# /home/astro/phrdhx/automated_exocomet_hunt

# %%
from analysis_tools_cython import *

# %%
data, info = import_XRPlightcurve('/storage/astro2/phrdhx/tesslcs/tesslcs_sector_6_104/tesslcs_tmag_5_6/tesslc_263935628.pkl',sector=6,clip=2)

# %%
data
# Out:
# <Table length=754>
#        time           raw flux    ...     flux error     quality
#      float64          float64     ...      float64        int32
# ------------------ -------------- ... ------------------ -------
#   1469.12062688441 176151.3828125 ... 11.451423216743185       0
# 1469.1414606337446 176165.2421875 ... 11.451806631360412       0
# 1469.1831281361385  176157.296875 ...  11.45162841677969       0
# 1469.2039618887159 176143.7890625 ... 11.451146057609904       0
# 1469.2456293952162  176144.328125 ... 11.451232337434186       0
# 1469.2872969013906 176144.4296875 ... 11.451017469483913       0
# 1469.3081306535205  176157.328125 ... 11.451488508062738       0
# 1469.3289644045606   176158.34375 ... 11.451586111228899       0
# 1469.3497981541761 176166.3359375 ... 11.451795971874688       0
# 1469.3706319020453 176165.7734375 ... 11.452003163850582       0
#                ...            ... ...                ...     ...
# ...

# %%
plt.plot(data['time'],data['corrected flux'])
