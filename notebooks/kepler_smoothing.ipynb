# %%
cd ..
# Out:
# /home/astro/phrdhx/automated_exocomet_hunt

# %%
from analysis_tools_cython import *
from wotan import flatten

# %%
table = import_lightcurve('kepler/kplr003542116-2012088054726_llc.fits',drop_bad_points=True)[0]

# %%
plt.figure(figsize=(20,10))
plt.plot(table['TIME'],table['PDCSAP_FLUX'])

# %%
flattened_flux, trend_flux = flatten(time=table['TIME'],flux=table['PDCSAP_FLUX'],method='lowess',window_length=2.5,return_trend=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-4c3f528f6b55> in <module>
# ----> 1 flattened_flux, trend_flux = flatten(time=table['TIME'],flux=table['PDCSAP_FLUX'],method='lowess',window_length=2.5,return_trend=True)
#
# ~/.local/lib/python3.7/site-packages/wotan/flatten.py in flatten(time, flux, window_length, edge_cutoff, break_tolerance, cval, return_trend, method, kernel, kernel_size, kernel_period, proportiontocut, robust, max_splines, stdev_cut, return_nsplines, mask, verbose)
#     249             )
#     250         elif method == "lowess":
# --> 251             trend_segment = lowess(time_view, flux_view, mask_view, window_length)
#     252         elif method == "hspline":
#     253             trend_segment = detrend_huber_spline(
#
# TypeError: expected dtype object, got 'numpy.dtype[float64]'
