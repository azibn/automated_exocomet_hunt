# %% [markdown]
# # Sector 4

# %%
import os
os.chdir('../../scripts')
import pandas as pd
import matplotlib.pyplot as plt
from post_processing import get_output
from analysis_tools_cython import *
import seaborn as sns
plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Import Data

# %%
data = get_output('../output_log/s4.txt')
print(len(data))
metadata = pd.read_csv('/storage/astro2/phrdhx/eleanor_copies/sector4lookup.csv')
print(len(metadata[metadata.Magnitude < 13]))
# Out:
# 242018
# 242018

# %%
data = data[data.transit_prob == 'maybeTransit']
print(len(data), f"after maybeTransit, {round(len(data)/len(metadata[metadata.Magnitude < 13]),3)*100}% candidates remain")
data.head()
# Out:
# 75016 after maybeTransit, 31.0% candidates remain
#                                                  path     TIC_ID   signal  \
# 17  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_11...  153740803 -8.64490
# 18  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_10...   36830129 -7.02941
# 20  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_10...  231722225 -3.33520
# 27  /tmp/tess/tesslcs_sector_4_104/2_min_cadence_t...  369378695 -4.15903
# 29  /tmp/tess/tesslcs_sector_4_104/2_min_cadence_t...  101001823 -4.01158
#
#         snr        time  asym_score  amplitude     width  skewness  \
# 17 -3.10899  1430.18009     0.93547    0.00000  10.43751 -30.00000
# 18 -3.60907  1435.18285     0.99935    0.00092   0.25831   0.00551
# 20 -2.98369  1430.36667     1.00474    0.00062   0.65229  -2.80891
# 27 -3.22435  1430.01413     0.99997    0.00040   0.21999  -0.00653
# 29 -3.68570  1433.18046     0.99978    0.00027   0.39483   0.00630
#
#     skewness_err  ...     n  chisq_gauss  chisq_skew  rchisq_gauss  \
# 17       0.00000  ...   791    813.47461   869.87654       4.96021
# 18   39269.55327  ...  1031    103.13590   103.07158       2.34400
# 20       6.28510  ...   799    160.43050   159.60117       2.86483
# 27   78045.96241  ...   783    130.88862   130.88492       1.07286
# 29  848308.95688  ...   935     53.07951    53.06833       2.04152
#
#     rchisq_skew  rmse_gauss  rmse_skew  mae_gauss  mae_skew  transit_prob
# 17      5.30413     0.00108    0.00112    0.00083   0.00088  maybeTransit
# 18      2.34254     0.00050    0.00050    0.00037   0.00037  maybeTransit
# 20      2.85002     0.00056    0.00056    0.00035   0.00035  maybeTransit
# 27      1.07283     0.00095    0.00095    0.00076   0.00076  maybeTransit
# 29      2.04109     0.00032    0.00032    0.00027   0.00027  maybeTransit
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Removing worst anomalies

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].scatter(data.asym_score,abs(data.snr),s=5)
ax[0].set_xlabel("asymmetry")
ax[1].set_xlabel("skewness")
ax[0].set_ylabel("snr")
ax[1].scatter(data.skewness,abs(data.snr),s=5)
plt.show()

# %%
# for i in data.loc[abs(data.skewness >= 10) & abs(data.skewness <= 20)].path.head(): #4 x 4 grid for illustration purposes
#     lc, lc_info = import_XRPlightcurve(i,sector=6)
#     lc = lc['time','corrected flux','quality','flux error']
#     _, _ = processing(lc,lc_info=lc_info,method='median',make_plots=True)

# %%
data = data[(data.asym_score <= 3)].reset_index(drop=True)
data.head()
# Out:
#                                                 path     TIC_ID   signal  \
# 0  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_11...  153740803 -8.64490
# 1  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_10...   36830129 -7.02941
# 2  /tmp/tess/tesslcs_sector_4_104/tesslcs_tmag_10...  231722225 -3.33520
# 3  /tmp/tess/tesslcs_sector_4_104/2_min_cadence_t...  369378695 -4.15903
# 4  /tmp/tess/tesslcs_sector_4_104/2_min_cadence_t...  101001823 -4.01158
#
#        snr        time  asym_score  amplitude     width  skewness  \
# 0 -3.10899  1430.18009     0.93547    0.00000  10.43751 -30.00000
# 1 -3.60907  1435.18285     0.99935    0.00092   0.25831   0.00551
# 2 -2.98369  1430.36667     1.00474    0.00062   0.65229  -2.80891
# 3 -3.22435  1430.01413     0.99997    0.00040   0.21999  -0.00653
# 4 -3.68570  1433.18046     0.99978    0.00027   0.39483   0.00630
#
#    skewness_err  ...     n  chisq_gauss  chisq_skew  rchisq_gauss  \
# 0       0.00000  ...   791    813.47461   869.87654       4.96021
# 1   39269.55327  ...  1031    103.13590   103.07158       2.34400
# 2       6.28510  ...   799    160.43050   159.60117       2.86483
# 3   78045.96241  ...   783    130.88862   130.88492       1.07286
# 4  848308.95688  ...   935     53.07951    53.06833       2.04152
#
#    rchisq_skew  rmse_gauss  rmse_skew  mae_gauss  mae_skew  transit_prob
# 0      5.30413     0.00108    0.00112    0.00083   0.00088  maybeTransit
# 1      2.34254     0.00050    0.00050    0.00037   0.00037  maybeTransit
# 2      2.85002     0.00056    0.00056    0.00035   0.00035  maybeTransit
# 3      1.07283     0.00095    0.00095    0.00076   0.00076  maybeTransit
# 4      2.04109     0.00032    0.00032    0.00027   0.00027  maybeTransit
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Distribution of Asymmetry vs SNR, and Skewness vs SNR

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].scatter(data.asym_score,abs(data.snr),s=5)
ax[0].set_xlabel("asymmetry")
ax[1].set_xlabel("skewness")
ax[0].set_ylabel("snr")
ax[1].scatter(data.skewness,abs(data.snr),s=5)
plt.show()

# %% [markdown]
# #### Histogram of time and duration

# %%
fig, axes = plt.subplots(1, 2)

# Plot the histogram for 'time' in the first subplot
data['time'].hist(bins=50, ax=axes[0])
axes[0].set_title('Time Histogram')
axes[0].set_xlabel('Time')
axes[0].set_ylabel('Frequency')

# Plot the histogram for 'duration' in the second subplot
data['duration'].hist(bins=50, ax=axes[1])
axes[1].set_title('Duration Histogram')
axes[1].set_xlabel('Duration')
axes[1].set_ylabel('Frequency')

# Adjust layout to prevent overlapping of titles and labels
plt.tight_layout()

# Show the subplots
plt.show()

# %% [markdown]
# #### 2D Histogram of time and duration

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

# Plot the first hist2d on the first subplot
h1 = ax1.hist2d(data['time'], data['duration'], bins=[20, 20])
ax1.set_title('2D Histogram - All Data')
ax1.set_xlabel('Time')
ax1.set_ylabel('Duration')
plt.colorbar(h1[3], ax=ax1)

# Plot the second hist2d on the second subplot
filtered_data = data[data.duration <= 0.2]
h2 = ax2.hist2d(filtered_data['time'], filtered_data['duration'], bins=[20, 20])
ax2.set_title('2D Histogram - Duration <= 0.2')
ax2.set_xlabel('Time')
ax2.set_ylabel('Duration')
plt.colorbar(h2[3], ax=ax2)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Alternative visualisation

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25,6))

# Plot the first histogram on the first subplot
data.loc[(data.time >= 1392.5) & (data.time <= 1395)].hist('time', bins=50, ax=ax1)
ax1.set_title('Time')
ax1.set_xlabel('Time')
ax1.set_ylabel('Frequency')

# Plot the second histogram on the second subplot
data.loc[(data.time >= 1392.5) & (data.time <= 1395)].hist('duration', bins=50, ax=ax2)
ax2.set_title('Duration')
ax2.set_xlabel('Duration')
ax2.set_ylabel('Frequency')

data.loc[(data.time >=1392.5) & (data.time <= 1395)].hist('duration',bins=50,ax=ax3)
ax3.set_title('Duration zoomed in')
ax3.set_xlabel('Duration')
ax3.set_ylabel('Frequency')
ax3.set_xlim([0,0.2])

plt.tight_layout()
plt.show()

# %% [markdown]
# There is a second spike around 0.3 days... Proven in `asym_score vs depth` plots

# %%
data.drop(data[(data['duration'] <= 0.15) & (data['time'] >= 1473.433) & (data['time'] <= 1473.5)].index,inplace=True)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].scatter(data.asym_score,abs(data.snr),s=5)
ax[0].set_xlabel("asymmetry")
ax[1].set_xlabel("skewness")
ax[0].set_ylabel("snr")
ax[1].scatter(data.skewness,abs(data.snr),s=5)
ax[0].axhline(5,c='red')

plt.show()

# %%
for i in data[(data.time >=1392.5) & (data.time <=1395)].path.head(10): #4 x 4 grid for illustration purposes
    lc, lc_info = import_XRPlightcurve(i,sector=3)
    plt.figure(figsize=(12,5))
    plt.scatter(lc['time'],normalise_flux(lc['corrected flux']), s=5)
    plt.title(f' TIC {lc_info[0]}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-51ed9987fb2c> in <module>
#       1 for i in data[(data.time >=1392.5) & (data.time <=1395)].path.head(10): #4 x 4 grid for illustration purposes
# ----> 2     lc, lc_info = import_XRPlightcurve(i,sector=3)
#       3     plt.figure(figsize=(12,5))
#       4     plt.scatter(lc['time'],normalise_flux(lc['corrected flux']), s=5)
#       5     plt.title(f' TIC {lc_info[0]}')
#
# scripts/analysis_tools_cython.pyx in scripts.analysis_tools_cython.import_XRPlightcurve()
#
# ~/.conda/envs/auto_exo_lite/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# ~/.conda/envs/auto_exo_lite/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tess/tesslcs_sector_3_104/tesslcs_tmag_10_11/tesslc_272128758.pkl'

# %% [markdown]
# ---

# %% [markdown]
# ## SNR cut

# %%
data_new = data[abs(data.snr) >= 5].reset_index(drop=True)

# %%
len(data_new[data_new.asym_score <= 0.2])
# Out:
# 13

# %%
plt.scatter(data_new['asym_score'],abs(data_new.snr),s=5)

# %%
for i in data.loc[abs(data.asym_score >= 1) & abs(data.asym_score <= 1.2)].path.head(): #4 x 4 grid for illustration purposes
    lc, lc_info = import_XRPlightcurve(i,sector=6)
    lc = lc['time','corrected flux','quality','flux error']
    _, _ = processing(lc,lc_info=lc_info,method='median',make_plots=True)

# %% [markdown]
# ---
# ## Other property cuts

# %% [markdown]
# ### Import EB catalogue

# %%
ebs = pd.read_csv('../eb_cat.txt')
tois = pd.read_csv('../exofop_tess_tois.csv')

tois = tois.reset_index()
tois = tois['level_0'][1:]
tois = tois.values.astype(int)

# %%
data_new
# Out:
#                                                     path     TIC_ID    signal  \
# 0      /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_11...  147367977 -17.68132
# 1      /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  381977181  -9.40107
# 2      /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  234080337 -15.49421
# 3      /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  381977351 -13.16631
# 4      /tmp/tess/tesslcs_sector_6_104/2_min_cadence_t...  365637508 -21.20106
# ...                                                  ...        ...       ...
# 13889  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   96735828 -23.68783
# 13890  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   55650494 -17.66076
# 13891  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   55650498 -15.54350
# 13892  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   96736720 -12.44552
# 13893  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   55652798  -7.56939
#
#             snr        time  asym_score  amplitude    width  skewness  \
# 0      -7.51427  1481.41127     1.00735    0.02017  0.06290  -0.56814
# 1      -5.78758  1476.84518     1.04831    0.00446  0.04075 -30.00000
# 2      -8.86215  1486.64140     1.02940    0.00077  0.07886   1.43976
# 3      -6.93674  1476.80356     0.40328    0.05124  0.54743  30.00000
# 4      -6.56150  1473.30808     0.81585    0.22070  0.34709   5.39584
# ...         ...         ...         ...        ...      ...       ...
# 13889 -10.98125  1475.47251     1.03050    0.00166  0.08111  -1.35116
# 13890  -9.21047  1488.11525     0.99939    0.03214  0.03892   0.00463
# 13891  -9.11367  1488.11525     1.00000    0.00117  0.03717  -0.00771
# 13892  -7.29587  1480.53505     1.07827    0.00092  0.08550  -2.92947
# 13893  -5.27270  1485.13610     1.10556    0.00143  0.26465  -3.93034
#
#        skewness_err  ...    n   chisq_gauss    chisq_skew  rchisq_gauss  \
# 0           0.39951  ...  595     189.48682     187.57793       4.98650
# 1       26310.81447  ...  368   14478.13700   13816.21877     723.90685
# 2           0.65164  ...  846      78.96996      76.12120       1.79477
# 3          43.35208  ...  366  200122.95539  167665.08810    3227.78960
# 4           1.60331  ...  206  354130.51154  239647.22230    3405.10107
# ...             ...  ...  ...           ...           ...           ...
# 13889       0.48245  ...  308      34.94993      33.80625       0.69900
# 13890    4256.12380  ...  909     361.79954     361.56780      13.91537
# 13891    7373.92723  ...  909      10.32484      10.32483       0.39711
# 13892       1.13375  ...  551      22.62060      20.98398       0.59528
# 13893       3.02141  ...  766      23.65947      21.39759       0.73936
#
#        rchisq_skew  rmse_gauss  rmse_skew  mae_gauss  mae_skew  transit_prob
# 0          4.93626     0.00266    0.00265    0.00205   0.00206  maybeTransit
# 1        690.81094     0.01442    0.01409    0.00990   0.00976  maybeTransit
# 2          1.73003     0.00042    0.00041    0.00032   0.00032  maybeTransit
# 3       2704.27561     0.02256    0.03553    0.01349   0.02921  maybeTransit
# 4       2304.30021     0.10450    0.11569    0.06514   0.06347  maybeTransit
# ...            ...         ...        ...        ...       ...           ...
# 13889      0.67613     0.00067    0.00066    0.00052   0.00053  maybeTransit
# 13890     13.90645     0.00477    0.00477    0.00311   0.00309  maybeTransit
# 13891      0.39711     0.00085    0.00085    0.00065   0.00065  maybeTransit
# 13892      0.55221     0.00078    0.00075    0.00061   0.00059  maybeTransit
# 13893      0.66867     0.00138    0.00131    0.00112   0.00106  maybeTransit
#
# [13894 rows x 25 columns]

# %%
ebs_found = data_new[data_new['TIC_ID'].isin(ebs['ID'])]
tois_found =  data_new[data_new['TIC_ID'].isin(tois)]

# %%
# Step 1: Create a boolean mask
data_new['is_eb'] = data_new['TIC_ID'].isin(ebs['ID'])
data_new['is_toi'] = data_new['TIC_ID'].isin(tois)

# %%
log_peak_power = np.log10(data_new['peak_lspower'])
log_depth = np.log10(abs(data_new['depth']))

# %%
len(data_new)
# Out:
# 13894

# %% [markdown]
# ### Duration vs depth

# %%
frac_dur = data_new.duration[(data_new.is_eb == False) & (data_new.is_toi == False)]
frac_depth = data_new.depth[(data_new.is_eb == False) & (data_new.is_toi == False)]

# %%
fig, ax = plt.subplots(ncols=2)

ax[0].scatter(data_new.duration,log_depth,s=20,label='candidates',zorder=1)
ax[0].scatter(ebs_found.duration,np.log10(abs(ebs_found['depth'])),c='orange',s=20,label='ebs')
ax[0].scatter(tois_found.duration,np.log10(abs(tois_found['depth'])),c='black',s=20,label='tois')

ax[1].scatter(frac_dur,np.log10(abs(frac_depth)),s=20,label='candidates',zorder=1)
#ax[1].scatter(tois_found.duration,np.log10(abs(tois_found['depth'])),c='black',s=20,label='tois')



ax[0].set_xlabel('duration')
ax[0].set_ylabel('log(abs(depth))')
ax[0].axvline(0.4,c='red')

plt.legend()

# %% [markdown]
# ### Duration vs Peak_lspower

# %%
plt.scatter(data_new.duration,data_new.peak_lspower,s=20,label='candidates')
plt.scatter(ebs_found.duration,ebs_found.peak_lspower,c='orange',s=20,label='ebs')
plt.scatter(tois_found.duration,tois_found.peak_lspower,c='black',s=20,label='tois')

plt.xticks(np.arange(0,1.75,0.1))
plt.xlabel('duration')
plt.ylabel('log peak power')
plt.axvline(0.4,c='red')
plt.legend()

# %%
plt.scatter(data_new.duration,log_peak_power,s=20,label='candidates')
plt.scatter(ebs_found.duration,np.log10(ebs_found['peak_lspower']),c='orange',s=20,label='ebs')
plt.scatter(tois_found.duration,np.log10(tois_found['peak_lspower']),c='black',s=20,label='tois')

plt.xticks(np.arange(0,1.75,0.1))
plt.xlabel('duration')
plt.ylabel('log peak power')
plt.axvline(0.4,c='red')
plt.legend()

# %%
crossref_tot = (ebs_found.duration) + (tois_found.duration) / data_new.duration
crosref_ebs = (ebs_found.duration) / data_new.duration
cross_ref_toi = (tois_found.duration) / data_new.duration

# %% [markdown]
# ### duration vs SNR

# %%
plt.scatter(data_new.duration,abs(data_new.snr),s=20,label='candidates')
plt.scatter(ebs_found.duration,abs(ebs_found.snr),c='orange',s=20,label='ebs')
plt.scatter(tois_found.duration,abs(tois_found.snr),c='black',s=20,label='tois')
plt.xlabel('duration')
plt.ylabel('snr')
# Out:
# Text(0, 0.5, 'snr')

# %% [markdown]
# ### asymmetry vs depth

# %%
plt.scatter(data_new.asym_score,abs(data_new.depth),s=20,label='candidates')
plt.ylim([0,1])
plt.xlabel('asym_score')
plt.ylabel('depth')
plt.xticks(np.arange(0,3,0.25))
plt.show()

# %%
test = data_new[(data_new.asym_score >=0.75) & (data_new.asym_score <= 0.85)]

# %% [markdown]
# #### Explore spike at ~0.8

# %%
for i in data_new[(data_new.asym_score >=0.75) & (data_new.asym_score <= 0.85)].path.head(2): #4 x 4 grid for illustration purposes
    lc, lc_info = import_XRPlightcurve(i,sector=6)
    plt.figure(figsize=(12,5))
    plt.scatter(lc['time'],normalise_flux(lc['corrected flux']), s=5)
    plt.title(f' TIC {lc_info[0]}')
    plt.show()

# %% [markdown]
# ### Spike at `asym_score ~ 1`
#
# Expected. But nevertheless, let's see

# %%
for i in data_new[(data_new.asym_score >=0.9) & (data_new.asym_score <= 1) & (abs(data_new.depth) >= 0.1)].path.head(2): #4 x 4 grid for illustration purposes
    print(len(data_new[(data_new.asym_score >=0.9) & (data_new.asym_score <= 1) & (abs(data_new.depth) >= 0.1)]))
    lc, lc_info = import_XRPlightcurve(i,sector=6)
    plt.figure(figsize=(12,5))
    plt.scatter(lc['time'],normalise_flux(lc['corrected flux']), s=5)
    plt.title(f' TIC {lc_info[0]}')
    plt.show()
# Out:
# 759
# 759

# %% [markdown]
# ### Make cut on 0.4 day duration

# %%
data_new.drop(data_new[data_new['duration'] <= 0.4].index,inplace=True)

# %%
data_new.head()
# Out:
#                                                  path     TIC_ID    signal  \
# 21  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_11...  119689578  -9.93499
# 24  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_11...  119689952  -9.53722
# 28  /tmp/tess/tesslcs_sector_6_104/2_min_cadence_t...  365746782 -19.35356
# 31  /tmp/tess/tesslcs_sector_6_104/2_min_cadence_t...  365747781  -9.05362
# 42  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  229172474 -17.04166
#
#         snr        time  asym_score  amplitude    width  skewness  \
# 21 -6.53815  1480.97420     0.99246    0.00124  0.37095   4.61365
# 24 -5.49828  1480.99504     1.02597    0.00121  0.33495 -30.00000
# 28 -7.31018  1473.41228     0.95881    0.00372  0.31883   6.52423
# 31 -5.25317  1473.39141     0.91312    0.00072  0.17278  -0.32598
# 42 -6.50876  1473.41228     0.89494    0.00165  0.16819   0.00134
#
#     skewness_err  ...  chisq_skew  rchisq_gauss  rchisq_skew  rmse_gauss  \
# 21       6.52792  ...  1031.33758       6.47775      6.52745     0.00197
# 24     130.49315  ...   693.74974       4.04766      3.94176     0.00182
# 28       2.95372  ...   923.93038       7.20287      5.84766     0.00213
# 31       9.07848  ...   126.97013       0.74804      0.69764     0.00051
# 42  434604.85926  ...   968.87502       6.74347      6.13212     0.00113
#
#     rmse_skew  mae_gauss  mae_skew  transit_prob  is_eb  is_toi
# 21    0.00198    0.00124   0.00126  maybeTransit  False   False
# 24    0.00179    0.00113   0.00113  maybeTransit  False   False
# 28    0.00218    0.00106   0.00109  maybeTransit  False   False
# 31    0.00054    0.00041   0.00042  maybeTransit  False   False
# 42    0.00120    0.00073   0.00076  maybeTransit  False   False
#
# [5 rows x 27 columns]

# %% [markdown]
# ### asym_score vs depth
# depth spike at 0.3 days gone.
# - Most if not all the failed lightcurves should have been cut now.

# %%
from matplotlib.colors import ListedColormap

# %%
bin_colors = ['#1f78b4', '#33a02c', '#e31a1c', '#ff7f00', '#6a3d9a', '#b15928', '#a6cee3', '#b2df8a']

# Create a ListedColormap using the specific colors
custom_cmap = ListedColormap(bin_colors)

# %%
bin_interval = 0.1
bins = np.arange(0, np.max(data_new.duration) + bin_interval, bin_interval)

# Use np.digitize to map duration values to their corresponding bins
duration_binned = bins[np.digitize(data_new.duration, bins) - 1]


plt.scatter(data_new.asym_score,abs(data_new.depth),c=duration_binned,s=20,label='candidates',cmap=custom_cmap)
plt.ylim([0,1])
plt.xlim([-0.1,2])
plt.xlabel('asym_score')
plt.ylabel('depth')
plt.xticks(np.arange(0,3,0.25))
plt.legend()
plt.colorbar(label='Duration')
plt.show()

# %%
data_new['abs_depth'] = abs(data_new.depth)
data_new.hist('abs_depth',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f20a856a050>]],
#       dtype=object)

# %% [markdown]
# Most are low amplitude transits

# %%
data_new[data_new.abs_depth <= 0.001].hist('abs_depth',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f20b385df10>]],
#       dtype=object)

# %%
data_new[data_new.abs_depth <= 0.001]
# Out:
#                                                     path     TIC_ID    signal  \
# 79     /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  234116467 -16.09377
# 161    /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_11...  232226413  -9.81396
# 297    /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  237390567  -5.94931
# 339    /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_10...  282267615  -7.42700
# 343    /tmp/tess/tesslcs_sector_6_104/2_min_cadence_t...   50898809 -10.42099
# ...                                                  ...        ...       ...
# 13389  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   52277263  -6.32649
# 13420  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_9_...   52920741  -4.35497
# 13561  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...   52290341  -7.87437
# 13746  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_9_...   33989737  -9.88956
# 13755  /tmp/tess/tesslcs_sector_6_104/tesslcs_tmag_12...  443548895 -11.28273
#
#            snr        time  asym_score  amplitude    width  skewness  \
# 79    -6.55132  1486.47466     0.57567    0.00000  1.35509  26.50185
# 161   -5.11938  1474.37056     0.76251    0.00000  0.00002 -29.99999
# 297   -5.24189  1486.03464     0.99998    0.00014  0.12741   0.00853
# 339   -5.27489  1474.43305     0.93660    0.00000  7.43749 -29.99648
# 343   -5.23923  1485.55762     1.00078    0.00027  0.28108   1.06031
# ...        ...         ...         ...        ...      ...       ...
# 13389 -5.43530  1480.43068     0.89347    0.00000  0.00000  30.00000
# 13420 -5.16122  1474.40974     1.00274    0.00025  0.80227  23.56846
# 13561 -5.77035  1473.45413     0.86396    0.00000  6.14151  28.69808
# 13746 -5.83580  1481.24459     0.82514    0.00000  8.18748 -29.99975
# 13755 -5.26221  1487.99460     0.66396    0.00000  0.00000 -30.00000
#
#        skewness_err  ...  rchisq_gauss  rchisq_skew  rmse_gauss  rmse_skew  \
# 79          0.00000  ...      83.53593    142.80709     0.00081    0.00107
# 161         0.00000  ...       1.84251      2.42135     0.00095    0.00109
# 297     43224.84705  ...       1.40148      1.40146     0.00041    0.00041
# 339         0.00000  ...       3.23469      3.45834     0.00076    0.00078
# 343         1.71074  ...       1.57064      1.56942     0.00018    0.00018
# ...             ...  ...           ...          ...         ...        ...
# 13389       0.00000  ...       0.42308      0.47465     0.00129    0.00137
# 13420     228.80986  ...      17.53001     17.47370     0.00114    0.00114
# 13561       0.00000  ...       4.46778      5.49623     0.00063    0.00068
# 13746       0.00000  ...       2.11782      2.57756     0.00035    0.00039
# 13755       0.00000  ...       1.01581      1.53170     0.00170    0.00208
#
#        mae_gauss  mae_skew  transit_prob  is_eb  is_toi  abs_depth
# 79       0.00061   0.00084  maybeTransit  False   False    0.00000
# 161      0.00075   0.00084  maybeTransit  False   False    0.00030
# 297      0.00032   0.00032  maybeTransit  False   False    0.00043
# 339      0.00064   0.00066  maybeTransit  False   False    0.00000
# 343      0.00014   0.00014  maybeTransit  False   False    0.00048
# ...          ...       ...           ...    ...     ...        ...
# 13389    0.00097   0.00103  maybeTransit  False   False    0.00000
# 13420    0.00092   0.00092  maybeTransit  False   False    0.00025
# 13561    0.00049   0.00049  maybeTransit  False   False    0.00000
# 13746    0.00029   0.00032  maybeTransit  False   False    0.00000
# 13755    0.00130   0.00161  maybeTransit  False   False    0.00000
#
# [103 rows x 28 columns]

# %%
for i in data_new[data_new.asym_score <= 0.01].path.head(10): #4 x 4 grid for illustration purposes
    lc, lc_info = import_XRPlightcurve(i,sector=6)
    lc = lc['time','corrected flux','quality','flux error']
    results, _ = processing(lc,lc_info=lc_info,method='median',make_plots=True)
    #plt.figure(figsize=(12,5))
    #plt.scatter(lc['time'],normalise_flux(lc['corrected flux']), s=5)
    #plt.title(f' TIC {lc_info[0]}')
    #plt.show()

# %% [markdown]
# ### Make cut at `> 0.1` and `< 0` depth

# %%
data_new.drop(data_new[(data_new['abs_depth'] >= 0.1)].index,inplace=True)

# %%
plt.scatter(data_new.asym_score,abs(data_new.depth),s=20,label='candidates',cmap=custom_cmap)
plt.ylim([0,0.1])
plt.xlabel('asym_score')
plt.ylabel('depth')
plt.xticks(np.arange(0,3,0.25))
plt.legend()
plt.colorbar(label='Duration')
plt.show()

# %%
plt.scatter(data_new.asym_score,abs(data_new.snr),s=20,label='candidates',cmap=custom_cmap)
plt.xlabel('asym_score')
plt.ylabel('snr')
plt.legend()
plt.show()

# %% [markdown]
# - 0.1 == 10% depth
# - 0.01 == 1% depth
# - 0.001 == 0.1% depth

# %% [markdown]
# ### SNR vs depth

# %%
plt.scatter(data_new.depth,abs(data_new.snr),s=20,label='candidates',cmap=custom_cmap)
plt.xlabel('depth')
plt.ylabel('snr')
plt.legend()
plt.show()

# %% [markdown]
# ## Make SOM Cutouts

# %%
os.getcwd()
# Out:
# '/home/astro/phrdhx/automated_exocomet_hunt/scripts'

# %%
os.chdir('../')
for i in data_new.path:
    lc, lc_info = import_XRPlightcurve(i,sector=6)
    lc = lc['time','corrected flux','quality','flux error']
    results, _ = processing(lc,lc_info=lc_info,method='median',som_cutouts=True)
    #plt.scatter(data['TIME'],data['PDCSAP_FLUX'],s=2)
