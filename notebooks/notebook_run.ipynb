# %%
cd ..
# Out:
# /home/astro/phrdhx/automated_exocomet_hunt

# %%
ls
# Out:
# 7175/
# analysis_tools_cython.c
# analysis_tools_cython.cpython-37m-x86_64-linux-gnu.so*
# analysis_tools_cython.pyx
# archive_analyse.sh*
# batch_analyse.py*
# batch_analyse_test.py*
# batch_reanalyse_asym.py*
# betapic/
# build/
# data/
# environment.yml
# figs/
# figs.ipynb
# figs_tess/
# gif/
# kepler/
# loaders.py
# mad_figs/
# make*
# notebooks/
# output_s4_corr.txt
# output_s5_corr.txt
# output_s6_corr.txt
# output_s6_pca.txt
# output_s6_raw.txt
# output_s6_spoc2min.txt
# output_s7_corr.txt
# output_spoc30min_s6.txt
# output.txt
# plots/
# post_processing_tools.py
# __pycache__/
# README.md
# setup.py*
# single_analysis.py
# single_analysis_test.py
# sky_positions.py
# spoc test.png
# tess_testlcs/
# tic_ra_dec.py

# %%
from analysis_tools_cython import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from analysis_tools_cython import *
#
# ModuleNotFoundError: No module named 'analysis_tools_cython'

# %%
# %run -i batch_analyse_test.py betapic/ -f "corrected flux" -p
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/automated_exocomet_hunt/batch_analyse_test.py in <module>
#     114 if __name__ == '__main__':
#     115
# --> 116     sector_test = args.path[0].split('_')[-2] # int(input("Sector? ")) # this is the case for XRP lightcurves... This is not required for mission lightcurves so it is ok to not consider them.
#     117     pool = multiprocessing.Pool(processes=args.threads)
#     118
#
# IndexError: list index out of range

# %% [markdown]
# #### `single_analysis` on 30 minute - Sector 6

# %%
# %run -i single_analysis.py /storage/astro2/phsqzm/TESS/SPOC_30min/S06/target/0000/0002/7057/7175/hlsp_tess-spoc_tess_phot_0000000270577175-s0006_tess_v1_lc.fits

# %% [markdown]
# #### `single_analysis` on 2 minute - Sector 6

# %%
# %run -i single_analysis.py tess_testlcs/spoc_2min/S6/tess2018349182459-s0006-0000000270577175-0126-s_lc.fits
# Out:
# Timestep of lightcurve:  2.0 minutes.
# Maximum transit chance:
#    Time = 1486.28 days.
#    Duration = 0.58 days.
#    T = -44.1
#    T/sigma = -5.6
# Transit depth = -0.001284
# Asym score: 0.9981
# Quality flags: 0
# maybeTransit

# %% [markdown]
# #### New `single_analysis` on Kepler

# %%
# %run -i single_analysis.py kepler/kplr003542116-2012088054726_llc.fits
# Out:
# Timestep of lightcurve:  29.425 minutes.
# Maximum transit chance:
#    Time = 1175.75 days.
#    Duration = 0.47 days.
#    T = -39.5
#    T/sigma = -9.6
# Transit depth = -0.000873
# Asym score: 2.1231
# Quality flags: 8192
# maybeTransit

# %% [markdown]
# ---
