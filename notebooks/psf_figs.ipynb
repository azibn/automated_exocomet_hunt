# %% [markdown]
# # Candidates v3

# %%
import lightkurve as lk
import eleanor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# ## TIC 280832588

# %%
star = eleanor.Source(tic=280832588, sector=1)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-3-4-cal-1196-0754_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-3-4-cal-1196-0754_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-3-4-cal-1196-0754_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-3-4-cal-1196-0754_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-3-4-cal-1196-0754_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-3-4_tess_v2_pm.txt with expected size 239582. [astroquery.query]
# ...

# %%
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)

# %% [markdown]
# ## TIC 270577175

# %%
star = eleanor.Source(tic=270577175, sector=6)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0006-3-3-cal-1686-0592_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0006-3-3-cal-1686-0592_tess_v2_bkg.fits with expected size 61162560. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0006-3-3-cal-1686-0592_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0006-3-3-cal-1686-0592_tess_v2_pc.fits with expected size 122411520. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0006-3-3-cal-1686-0592_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0006-3-3_tess_v2_pm.txt with expected size 185294. [astroquery.query]
# ...

# %%
#plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[6,10], rowrange=[6,10],ylim=[0.99,1.01],xlim=[1915,1925],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %% [markdown]
# ## TIC 172537088 (CHSS 93) - ruled out, event is happening from nearby Gaia DR3 star.

# %%
# star = eleanor.Source(tic=172537088, sector=22)
# data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
# q = data.quality == 0

# %%
# vis = eleanor.Visualize(data)
# vis.pixel_by_pixel(colrange=[6,10], rowrange=[6,10],ylim=[0.99,1.01],xlim=[1915,1925],color_by_pixel=True,)

# %%
# vis.aperture_contour()

# %%
# plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)
# plt.ylim(0.99,1.01)

# %% [markdown]
# ## TIC 131422529 - ruled out. No signal in PSF

# %%
star = eleanor.Source(tic=131422529, sector=7)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-3-1-cal-0902-0808_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-3-1-cal-0902-0808_tess_v2_bkg.fits with expected size 67317120. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-3-1-cal-0902-0808_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-3-1-cal-0902-0808_tess_v2_pc.fits with expected size 134729280. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-3-1-cal-0902-0808_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-3-1_tess_v2_pm.txt with expected size 203375. [astroquery.query]
# ...

# %%
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)
plt.xlim([1491,1500])
# Out:
# (1491.0, 1500.0)

# %% [markdown]
# ## TIC 73149665 - Possible, one more vetting check I think with `bruce`

# %%
star = eleanor.Source(tic=73149665, sector=12)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0012-2-4-cal-0706-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0012-2-4-cal-0706-0970_tess_v2_bkg.fits with expected size 79384320. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0012-2-4-cal-0706-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0012-2-4-cal-0706-0970_tess_v2_pc.fits with expected size 158883840. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0012-2-4-cal-0706-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0012-2-4_tess_v2_pm.txt with expected size 240982. [astroquery.query]
# ...

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],xlim=[1645,1652],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %% [markdown]
# # Giants

# %% [markdown]
# ## TIC 110969638 - check the pixel-by-pixel lightcurve

# %%
star = eleanor.Source(tic=110969638, sector=7)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-2-2-cal-0510-0916_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-2-2-cal-0510-0916_tess_v2_bkg.fits with expected size 67317120. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-2-2-cal-0510-0916_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-2-2-cal-0510-0916_tess_v2_pc.fits with expected size 134729280. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0007-2-2-cal-0510-0916_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0007-2-2_tess_v2_pm.txt with expected size 203947. [astroquery.query]
# ...

# %%
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)

# %%
plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]),s=10)

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],xlim=[1645,1652],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %% [markdown]
# ## TIC 349766841 - ruled out because there was no transit in the PSF

# %%
star = eleanor.Source(tic=349766841, sector=8)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0008-4-1-cal-1588-0160_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0008-4-1-cal-1588-0160_tess_v2_bkg.fits with expected size 59621760. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0008-4-1-cal-1588-0160_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0008-4-1-cal-1588-0160_tess_v2_pc.fits with expected size 119327040. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0008-4-1-cal-1588-0160_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0008-4-1_tess_v2_pm.txt with expected size 180513. [astroquery.query]
# ...

# %%
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)
#plt.ylim(0.9,1.03)
plt.xlim(1537,1545)
# Out:
# (1537.0, 1545.0)

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %% [markdown]
# ## TIC 192071317

# %%
star = eleanor.Source(tic=192071317, sector=20)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# WARNING: NoResultsWarning: Query returned no results. [astroquery.mast.discovery_portal]
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# ...

# %%
plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q])-0.01,s=5,label='CORR')
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=5,label='PSF')
plt.xlim([1845,1859])
plt.ylim([0.98,1.01])
# Out:
# (0.98, 1.01)

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %%
import eleanor
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## TIC 229790952

# %%
star = eleanor.Source(tic=229790952, sector=15)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# WARNING:tensorflow:From /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/targetdata.py:836: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/targetdata.py:836: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
# 100%|██████████| 1197/1197 [00:14<00:00, 81.84it/s]

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],ylim=[0.98,1.01],xlim=[1723,1736],color_by_pixel=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(15,6))
plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q])+0.01,s=10,label='CORR')
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10,label='PSF')
#plt.xlim([1723,1736])
#plt.ylim(0.99,1.01)

# %% [markdown]
# #### Different Sector

# %%
star = eleanor.Source(tic=229790952, sector=17)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# ...
# Inflating...
# 100%|██████████| 1130/1130 [00:13<00:00, 86.26it/s]

# %%
vis.plot_gaia_overlay(magnitude_limit=15)
# Out:
# <AxesSubplot:title={'center':'TIC 229790952'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %% [markdown]
# # Class B giants
# ## TIC 312314132

# %%
star = eleanor.Source(tic=312314132, sector=11)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0011-3-1-cal-1882-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0011-3-1-cal-1882-0970_tess_v2_bkg.fits with expected size 76861440. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0011-3-1-cal-1882-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0011-3-1-cal-1882-0970_tess_v2_pc.fits with expected size 153835200. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0011-3-1-cal-1882-0970_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0011-3-1_tess_v2_pm.txt with expected size 233949. [astroquery.query]
# ...

# %%
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]),s=10)
plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q])-0.01,s=10)

plt.xlim([1600,1610])
plt.ylim(0.97,1.03)
# Out:
# (0.97, 1.03)

# %%
vis = eleanor.Visualize(data)
vis.pixel_by_pixel(colrange=[5,10], rowrange=[5,10],ylim=[0.98,1.01],color_by_pixel=True)
# Out:
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
#   LightkurveDeprecationWarning,
# /home/astro/phrdhx/micromamba/envs/exocomet/lib/python3.7/site-packages/lightkurve/lightcurve.py:226: LightkurveDeprecationWarning: passing flux as a positional argument is deprecated, please use ``flux=...`` instead.
# ...

# %% [markdown]
# ## TIC 298933945 - ruled out, some periodic binary i think (algorithm caught the secondary eclipse)

# %%
star = eleanor.Source(tic=298933945, sector=9)
data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True)
q = data.quality == 0
# Out:
# /home/astro/phrdhx/.local/lib/python3.7/site-packages/eleanor/ffi.py:40: UserWarning: couldn't find pointing model
#   warnings.warn("couldn't find pointing model")
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0009-3-1-cal-1882-1024_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0009-3-1-cal-1882-1024_tess_v2_bkg.fits with expected size 71072640. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0009-3-1-cal-1882-1024_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0009-3-1-cal-1882-1024_tess_v2_pc.fits with expected size 142246080. [astroquery.query]
# INFO: Found cached file /home/astro/phrdhx/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0009-3-1-cal-1882-1024_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0009-3-1_tess_v2_pm.txt with expected size 215725. [astroquery.query]
# ...

# %%
plt.figure(figsize=(15,6))
plt.scatter(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]),s=10,label='CORR')
plt.scatter(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q])-0.01,s=10,label='PSF')
plt.xlim(1545,1555)
# Out:
# (1545.0, 1555.0)
