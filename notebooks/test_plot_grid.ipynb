# %%
import os
os.chdir('../')
from scripts.analysis_tools_cython import *

# %%
data, info = import_lightcurve("betapic/hlsp_tess-spoc_tess_phot_0000000270577175-s0006_tess_v1_lc.fits")
info
# Out:
# [270577175, 3.69569993, 6, 3, 3, 86.8212165826392, -51.0665035714537]

# %%
results, data = processing(data, lc_info=info,method='median',make_plots=True)

# %% [markdown]
# ---
# ## Testing if errors were normalised correctly...
